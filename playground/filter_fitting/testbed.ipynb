# %%
import numpy as np
import matplotlib.pyplot as plt
import IIRrational.v2
import scipy.signal as sig

# %%
z= [-76.4239112 + 199.90276042j, -76.4239112 - 199.90276042j, 58.28702394 + 234.017455j, 58.28702394 - 234.017455j, -75.66484992 + 68.3950040j, -75.66484992 - 68.3950040j]
p = [-145.84200443 + 0.40077142j, -145.84200443 - 0.40077142j, -622.74808103 + 197.1607109j, -622.74808103 - 197.1607109j]
k =  [1.0496737e-05 + 1.57217584e-12j]

# %%
 w, h = sig.freqs_zpk(z, p, k, worN=np.arange(0,1000,.1))

# %%
k =  [1.0496737e-05 + 1.57217584e-12j]/w[1]
w_1, h_1 = sig.freqresp((z, p, k), 2*np.pi*np.arange(0,1000,.1))

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.loglog(w, abs(h))
plt.show()

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.semilogx(w,np.angle(h))
plt.show()

# %%
# adding butter filter to 
num1, den1 = sig.butter(2,2e)
