# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
t = np.linspace(-1, 1, 201)
x = (np.sin(2*np.pi*0.75*t*(1-t) + 2.1) + 0.1*np.sin(2*np.pi*1.25*t + 1) + 0.18*np.cos(2*np.pi*3.85*t))
xn = x + np.random.randn(len(t)) * 0.08

# %%
#Load the Hartmann data
datay = np.loadtxt('ifo_thermal_response_12_07_2018/ITMY_HWS.dat')
datax = np.loadtxt('ifo_thermal_response_12_07_2018/ITMX_HWS.dat')

t = np.arange(0,len(data[:-1,0]),1)
HWSY = datay[:-1,1]
HWSX = datax[:-1,1]
xn = HWSY
plt.plot(t,HWSY)
plt.plot(t,HWSX)
plt.show()

# %%
b, a = signal.butter(2, 0.2)
c,d = signal.butter(4,.07)

# %%
zi = signal.lfilter_zi(b, a)
z, _ = signal.lfilter(b, a, xn, zi=zi*xn[0])

# %%
z2, _ = signal.lfilter(b, a, z, zi=zi*z[0])

# %%
y = signal.filtfilt(c, d, HWSX)
y2 = signal.filtfilt(b,a,HWSY)

# %%
plt.figure
plt.plot(t, HWSY, 'b', alpha=0.75)
plt.plot(t, z, 'r--', t, z2, 'r', t, y2, 'k')
plt.legend(('noisy signal', 'lfilter, once', 'lfilter, twice',
             'filtfilt'), loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure
plt.plot(t,HWSX,'g', alpha=.75)
plt.plot(t,y,'k')
plt.grid(True)
plt.show()
