# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ITMY_pa = np.load('ITMY_pa.npz')
ITMY_pa_mask = np.load('ITMY_pa_mask.npz')
ITMY_pa_mask_30W = np.load('ITMY_1234844470_1234849670.npz')

# %%
ITMY_pa.files
# Out:
# ['optic', 'reference', 'show', 'y', 'x', 'ifo', 'wavefront']

# %%
sum_wf = ITMY_pa['wavefront'] + 1.5*ITMY_pa_mask['wavefront']

# %%
diff_wf = ITMY_pa_mask_30W['wavefront']-ITMY_pa['wavefront']

# %%
plt.imshow(ITMY_pa_mask_30W['wavefront'], origin='lower')
plt.colorbar()

# %%
plt.imshow(ITMY_pa['wavefront'], origin='lower')
plt.colorbar()

# %%
plt.imshow(diff_wf, origin= 'lower')
plt.colorbar()

# %%
plt.imshow(ITMY_pa_mask['wavefront'],origin='lower')
plt.colorbar()

# %%
plt.imshow(sum_wf, origin='lower')
